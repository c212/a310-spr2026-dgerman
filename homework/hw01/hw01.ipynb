# %% [markdown]
# **Problem 1**. Define fair as having an expected value of $0$. Probability of rolling a $7$ is $\frac{6}{36} = \frac{1}{6}$. The expected value is $(4 \cdot \frac{1}{6} - 1 \cdot \frac{5}{6}) = -\frac{1}{6}$ which is not fair. Fair would be with $5$ instead of $4$ for a win.
