# %%
import numpy as np

# %%
a = np.array([1, 2, 3, 4, 5, 6, 7, 8])

# %%
a[7]
# Out:
# np.int64(8)

# %%
a.reshape(2, 4)
# Out:
# array([[1, 2, 3, 4],
#        [5, 6, 7, 8]])

# %%
a
# Out:
# array([1, 2, 3, 4, 5, 6, 7, 8])

# %%
b = a.reshape(2, 4)

# %%
b
# Out:
# array([[1, 2, 3, 4],
#        [5, 6, 7, 8]])

# %%
a
# Out:
# array([1, 2, 3, 4, 5, 6, 7, 8])

# %%
c = a.reshape(2, 2, 2)

# %%
c
# Out:
# array([[[1, 2],
#         [3, 4]],
#
#        [[5, 6],
#         [7, 8]]])

# %%
c[0]
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
c[1]
# Out:
# array([[5, 6],
#        [7, 8]])

# %%
c[:,:,0]
# Out:
# array([[1, 3],
#        [5, 7]])

# %%
c[::-1,:,0]
# Out:
# array([[5, 7],
#        [1, 3]])

# %%
np.transpose(c[:,:,0])
# Out:
# array([[1, 5],
#        [3, 7]])
